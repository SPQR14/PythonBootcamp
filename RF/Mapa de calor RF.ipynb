# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(font_scale=0.9)

# %%
beneficios_metricas = pd.read_csv("beneficios_metricas.csv", sep = ',', encoding = "utf8")

# %%
beneficios_metricas
# Out:
#                                            Unnamed: 0  Beneficios  Métricas
# 0                      Auntenticación facial en ATM´s          11         9
# 1                  Autenticación facial en portal Web          12         6
# 2   Contratación de productos y servicios con aute...          12         8
# 3   Autorización de operaciones con reconocimiento...          12         8
# 4        Autenticación facial en aplicaciones móviles          11        10
# 5                            Análisis forense en ATMs           9         4
# 6                Análisis forense con CCTV sucursales           9         4
# 7                  Sistema centralizado para tracking           9         4
# 8   Identificación de delincuentes en listas negra...           4         4
# 9   Identificación de personas listas blancas, lis...           2         7
# 10  Identificación delincuentes de listas negras e...           4         2
# ...

# %%
df = pd.read_csv("data_set_1.csv", sep = ',', encoding = 'utf8')

# %%
df
# Out:
#    Auntenticación facial en ATM´s  Autenticación facial en portal Web  \
# 0                               9                                   6
# 1                              11                                  12
#
#    Contratación de productos y servicios con autenticación facial en web  \
# 0                                                  8
# 1                                                 12
#
#    Autorización de operaciones con reconocimiento facial en web  \
# 0                                                  8
# 1                                                 12
#
#    Autenticación facial en aplicaciones móviles  Análisis forense en ATMs  \
# 0                                            10                         4
# 1                                            11                         9
#
#    Análisis forense con CCTV sucursales  Sistema centralizado para tracking  \
# 0                                     4                                   4
# ...

# %%
a = df.describe()

# %%
a
# Out:
#        Auntenticación facial en ATM´s  Autenticación facial en portal Web  \
# count                        2.000000                            2.000000
# mean                        10.000000                            9.000000
# std                          1.414214                            4.242641
# min                          9.000000                            6.000000
# 25%                          9.500000                            7.500000
# 50%                         10.000000                            9.000000
# 75%                         10.500000                           10.500000
# max                         11.000000                           12.000000
#
#        Contratación de productos y servicios con autenticación facial en web  \
# count                                           2.000000
# mean                                           10.000000
# std                                             2.828427
# ...

# %%
df_transpuesto = df.transpose()

# %%
df_transpuesto.head
# Out:
# <bound method NDFrame.head of                                                      0   1
# Auntenticación facial en ATM´s                       9  11
# Autenticación facial en portal Web                   6  12
# Contratación de productos y servicios con auten...   8  12
# Autorización de operaciones con reconocimiento ...   8  12
# Autenticación facial en aplicaciones móviles        10  11
# Análisis forense en ATMs                             4   9
# Análisis forense con CCTV sucursales                 4   9
# Sistema centralizado para tracking                   4   9
# Identificación de delincuentes en listas negras...   4   4
# Identificación de delincuentes en listas negras...   3   4
# Identificación de personas listas blancas, list...   7   2
# Identificación delincuentes de listas negras en...   2   4
# Identificar listas negras en edificios               5   3
# Control de acceso para áreas seguras                 4   8
# ...

# %%
df_transpuesto.describe()
# Out:
#               0          1
# count  25.00000  25.000000
# mean    4.80000   7.080000
# std     2.44949   3.213513
# min     2.00000   2.000000
# 25%     3.00000   4.000000
# 50%     4.00000   8.000000
# 75%     7.00000   9.000000
# max    10.00000  12.000000

# %%
df_transpuesto
# Out:
#                                                      0   1
# Auntenticación facial en ATM´s                       9  11
# Autenticación facial en portal Web                   6  12
# Contratación de productos y servicios con auten...   8  12
# Autorización de operaciones con reconocimiento ...   8  12
# Autenticación facial en aplicaciones móviles        10  11
# Análisis forense en ATMs                             4   9
# Análisis forense con CCTV sucursales                 4   9
# Sistema centralizado para tracking                   4   9
# Identificación de delincuentes en listas negras...   4   4
# Identificación de delincuentes en listas negras...   3   4
# Identificación de personas listas blancas, list...   7   2
# Identificación delincuentes de listas negras en...   2   4
# Identificar listas negras en edificios               5   3
# Control de acceso para áreas seguras                 4   8
# Control de accesos de personas en edificios          3   9
# ...

# %%
eje_y = ['Métricas', 'Beneficios']

# %%
ax = sns.heatmap(df, yticklabels = eje_y , linewidth=0.5, cmap="Blues")
#ax = sns.heatmap(df, linewidth=0.5)

# %%
plt.show()

# %%
ax

# %%
sns.pairplot(df_transpuesto ,size=4.5)
# Out:
# /home/spqr14/.local/lib/python3.7/site-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

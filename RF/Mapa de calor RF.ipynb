# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
import seaborn as sns
sns.set()

# %%
beneficios_metricas = pd.read_csv("beneficios_metricas.csv", sep = ',', encoding = "utf8")

# %%
beneficios_metricas
# Out:
#                                            Unnamed: 0  Beneficios  Métricas
# 0                      Auntenticación facial en ATM´s          11         9
# 1                  Autenticación facial en portal Web          12         6
# 2   Contratación de productos y servicios con aute...          12         8
# 3   Autorización de operaciones con reconocimiento...          12         8
# 4        Autenticación facial en aplicaciones móviles          11        10
# 5                            Análisis forense en ATMs           9         4
# 6                Análisis forense con CCTV sucursales           9         4
# 7                  Sistema centralizado para tracking           9         4
# 8   Identificación de delincuentes en listas negra...           4         4
# 9   Identificación de personas listas blancas, lis...           2         7
# 10  Identificación delincuentes de listas negras e...           4         2
# 11             Identificar listas negras en edificios           3         5
# 12               Control de acceso para áreas seguras           8         4
# 13        Control de accesos de personas en edificios           9         3
# 14           Control de acceso vehicular en edificios           8         3
# 15            Registro facial de visitas en edificios           8         4
# 16               Identificación de personas en podios           9         7
# 17  Reconocimiento de sentimientos de personas que...           4         3
# 18            Identificación de emociones desde podio           5         3
# 19             Identificación de emociones desde ATMs           4         3
# 20                    Autenticación facial documental           8         9
# 21               Reconocimiento de datos demográficos           4         3

# %%
df = pd.read_csv("data_set_1.csv", sep = ',', encoding = 'utf8')

# %%
df.head
# Out:
# <bound method NDFrame.head of    Auntenticación facial en ATM´s  Autenticación facial en portal Web  \
# 0                              11                                  12
# 1                               9                                   6
#
#    Contratación de productos y servicios con autenticación facial en web  \
# 0                                                 12
# 1                                                  8
#
#    Autorización de operaciones con reconocimiento facial en web  \
# 0                                                 12
# 1                                                  8
#
#    Autenticación facial en aplicaciones móviles  Análisis forense en ATMs  \
# 0                                            11                         9
# 1                                            10                         4
#
#    Análisis forense con CCTV sucursales  Sistema centralizado para tracking  \
# 0                                     9                                   9
# 1                                     4                                   4
#
#    Identificación de delincuentes en listas negras en tiempo real en ATMs y sucursales  \
# 0                                                  4
# 1                                                  4
#
#    Identificación de personas listas blancas, listas VIP en podios  ...  \
# 0                                                  2                ...
# 1                                                  7                ...
#
#    Control de acceso para áreas seguras  \
# 0                                     8
# 1                                     4
#
#    Control de accesos de personas en edificios  \
# 0                                            9
# 1                                            3
#
#    Control de acceso vehicular en edificios  \
# 0                                         8
# 1                                         3
#
#    Registro facial de visitas en edificios  \
# 0                                        8
# 1                                        4
#
#    Identificación de personas en podios  \
# 0                                     9
# 1                                     7
#
#    Reconocimiento de sentimientos de personas que visitan las sucursales con CCTV  \
# 0                                                  4
# 1                                                  3
#
#    Identificación de emociones desde podio  \
# 0                                        5
# 1                                        3
#
#    Identificación de emociones desde ATMs  Autenticación facial documental  \
# 0                                       4                                8
# 1                                       3                                9
#
#    Reconocimiento de datos demográficos
# 0                                     4
# 1                                     3
#
# [2 rows x 22 columns]>

# %%
a = df.describe()

# %%
a
# Out:
#        Auntenticación facial en ATM´s  Autenticación facial en portal Web  \
# count                        2.000000                            2.000000
# mean                        10.000000                            9.000000
# std                          1.414214                            4.242641
# min                          9.000000                            6.000000
# 25%                          9.500000                            7.500000
# 50%                         10.000000                            9.000000
# 75%                         10.500000                           10.500000
# max                         11.000000                           12.000000
#
#        Contratación de productos y servicios con autenticación facial en web  \
# count                                           2.000000
# mean                                           10.000000
# std                                             2.828427
# min                                             8.000000
# 25%                                             9.000000
# 50%                                            10.000000
# 75%                                            11.000000
# max                                            12.000000
#
#        Autorización de operaciones con reconocimiento facial en web  \
# count                                           2.000000
# mean                                           10.000000
# std                                             2.828427
# min                                             8.000000
# 25%                                             9.000000
# 50%                                            10.000000
# 75%                                            11.000000
# max                                            12.000000
#
#        Autenticación facial en aplicaciones móviles  Análisis forense en ATMs  \
# count                                      2.000000                  2.000000
# mean                                      10.500000                  6.500000
# std                                        0.707107                  3.535534
# min                                       10.000000                  4.000000
# 25%                                       10.250000                  5.250000
# 50%                                       10.500000                  6.500000
# 75%                                       10.750000                  7.750000
# max                                       11.000000                  9.000000
#
#        Análisis forense con CCTV sucursales  \
# count                              2.000000
# mean                               6.500000
# std                                3.535534
# min                                4.000000
# 25%                                5.250000
# 50%                                6.500000
# 75%                                7.750000
# max                                9.000000
#
#        Sistema centralizado para tracking  \
# count                            2.000000
# mean                             6.500000
# std                              3.535534
# min                              4.000000
# 25%                              5.250000
# 50%                              6.500000
# 75%                              7.750000
# max                              9.000000
#
#        Identificación de delincuentes en listas negras en tiempo real en ATMs y sucursales  \
# count                                                2.0
# mean                                                 4.0
# std                                                  0.0
# min                                                  4.0
# 25%                                                  4.0
# 50%                                                  4.0
# 75%                                                  4.0
# max                                                  4.0
#
#        Identificación de personas listas blancas, listas VIP en podios  ...  \
# count                                           2.000000                ...
# mean                                            4.500000                ...
# std                                             3.535534                ...
# min                                             2.000000                ...
# 25%                                             3.250000                ...
# 50%                                             4.500000                ...
# 75%                                             5.750000                ...
# max                                             7.000000                ...
#
#        Control de acceso para áreas seguras  \
# count                              2.000000
# mean                               6.000000
# std                                2.828427
# min                                4.000000
# 25%                                5.000000
# 50%                                6.000000
# 75%                                7.000000
# max                                8.000000
#
#        Control de accesos de personas en edificios  \
# count                                     2.000000
# mean                                      6.000000
# std                                       4.242641
# min                                       3.000000
# 25%                                       4.500000
# 50%                                       6.000000
# 75%                                       7.500000
# max                                       9.000000
#
#        Control de acceso vehicular en edificios  \
# count                                  2.000000
# mean                                   5.500000
# std                                    3.535534
# min                                    3.000000
# 25%                                    4.250000
# 50%                                    5.500000
# 75%                                    6.750000
# max                                    8.000000
#
#        Registro facial de visitas en edificios  \
# count                                 2.000000
# mean                                  6.000000
# std                                   2.828427
# min                                   4.000000
# 25%                                   5.000000
# 50%                                   6.000000
# 75%                                   7.000000
# max                                   8.000000
#
#        Identificación de personas en podios  \
# count                              2.000000
# mean                               8.000000
# std                                1.414214
# min                                7.000000
# 25%                                7.500000
# 50%                                8.000000
# 75%                                8.500000
# max                                9.000000
#
#        Reconocimiento de sentimientos de personas que visitan las sucursales con CCTV  \
# count                                           2.000000
# mean                                            3.500000
# std                                             0.707107
# min                                             3.000000
# 25%                                             3.250000
# 50%                                             3.500000
# 75%                                             3.750000
# max                                             4.000000
#
#        Identificación de emociones desde podio  \
# count                                 2.000000
# mean                                  4.000000
# std                                   1.414214
# min                                   3.000000
# 25%                                   3.500000
# 50%                                   4.000000
# 75%                                   4.500000
# max                                   5.000000
#
#        Identificación de emociones desde ATMs  \
# count                                2.000000
# mean                                 3.500000
# std                                  0.707107
# min                                  3.000000
# 25%                                  3.250000
# 50%                                  3.500000
# 75%                                  3.750000
# max                                  4.000000
#
#        Autenticación facial documental  Reconocimiento de datos demográficos
# count                         2.000000                              2.000000
# mean                          8.500000                              3.500000
# std                           0.707107                              0.707107
# min                           8.000000                              3.000000
# 25%                           8.250000                              3.250000
# 50%                           8.500000                              3.500000
# 75%                           8.750000                              3.750000
# max                           9.000000                              4.000000
#
# [8 rows x 22 columns]

# %%
df_transpuesto = df.transpose()

# %%
df_transpuesto.head
# Out:
# <bound method NDFrame.head of                                                      0   1
# Auntenticación facial en ATM´s                      11   9
# Autenticación facial en portal Web                  12   6
# Contratación de productos y servicios con auten...  12   8
# Autorización de operaciones con reconocimiento ...  12   8
# Autenticación facial en aplicaciones móviles        11  10
# Análisis forense en ATMs                             9   4
# Análisis forense con CCTV sucursales                 9   4
# Sistema centralizado para tracking                   9   4
# Identificación de delincuentes en listas negras...   4   4
# Identificación de personas listas blancas, list...   2   7
# Identificación delincuentes de listas negras en...   4   2
# Identificar listas negras en edificios               3   5
# Control de acceso para áreas seguras                 8   4
# Control de accesos de personas en edificios          9   3
# Control de acceso vehicular en edificios             8   3
# Registro facial de visitas en edificios              8   4
# Identificación de personas en podios                 9   7
# Reconocimiento de sentimientos de personas que ...   4   3
# Identificación de emociones desde podio              5   3
# Identificación de emociones desde ATMs               4   3
# Autenticación facial documental                      8   9
# Reconocimiento de datos demográficos                 4   3>

# %%
eje_x = ['Beneficios', 'Metricas']

# %%
ax = sns.heatmap(df_transpuesto, xticklabels = eje_x ,linewidths=.5)

# %%
np.corrcoef(df)
# Out:
# array([[1.        , 0.53833831],
#        [0.53833831, 1.        ]])
